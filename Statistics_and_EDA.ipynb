# %% [markdown]
# <a href="https://colab.research.google.com/github/chain-veerender/datascience/blob/master/Statistics_and_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
upload_file = files.upload()
# Out:
#      <input type="file" id="files-4257a8d6-5c1d-4796-aee4-b96070c63cb9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4257a8d6-5c1d-4796-aee4-b96070c63cb9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving iris.csv to iris (1).csv

# %%
import pandas as pd
import io
 
df_iris = pd.read_csv(io.BytesIO(upload_file['iris.csv']))
print(df_iris)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ![An image](https://miro.medium.com/max/628/1*mRRa-oIPVmqQLJ7LKwqidw.png)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#df_iris(columns={'sepal_length':'SL','sepal_width':'SW','petal_length':'PL','petal_width':'PW'},inplace=True)
iris_setosa=df_iris.loc[df_iris['variety'] == 'Setosa']
iris_versicolor=df_iris.loc[df_iris['variety']== 'Versicolor']
iris_virginica=df_iris.loc[df_iris['variety']== 'Virginica']

# %%
iris_setosa.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %% [markdown]
# ![An image](https://editor.analyticsvidhya.com/uploads/84942IQR.png)

# %% [markdown]
# ![An image](https://miro.medium.com/max/700/1*aiyxBv_4kz_T8C1A4o6MbQ.png)

# %%
print(np.percentile(iris_setosa['petal_length'],25))
print(np.percentile(iris_setosa['petal_length'],50))
print(np.percentile(iris_setosa['petal_length'],75))
print(np.percentile(iris_setosa['petal_length'],100))
# Out:
# 1.4
# 1.5
# 1.5750000000000002
# 1.9

# %% [markdown]
# ![An image](https://editor.analyticsvidhya.com/uploads/59570Normal%20Distribution.png)

# %% [markdown]
# If any data follows Normal or Gaussian distribution then it also follows three conditions known as Empirical Formula
#
# P[ mean – std_dev <= mean + std_dev] = 68 percent
#
# P[ mean – 2* std_dev <= mean + 2*std_dev] = 95 percent
#
# P[ mean – 3*std_dev <= mean + 3*std_dev] = 99.7 percent

# %% [markdown]
# ![An image](https://miro.medium.com/max/609/1*bRHNAqJP7GRtq4j5EFrT9w.png)

# %% [markdown]
# **Skewness**
#
# Skewness is a measure of the symmetry of distribution that you plot in form of a histogram, KDE which has a high peak towards the mode of data. skewness is generally of 2 types as left-skewed data and right-skewed data.

# %% [markdown]
# **Right Skewed Data(Positively skewed distribution)**
#
# Right skewed distribution means data that has a long tail towards the right side(Positive axis). A classical example of right-skewed is wealth distribution, there are very less few people who have very high wealth and maximum people are in the medium range.

# %% [markdown]
# **Left-skewed Data(Negatively skewed distribution)**
#
# Left skewed distribution means data that has a long tail towards the left side(negative axis). An example can be Grades of students, there will be fewer students who have received fewer grades and the maximum student will be in the pass category.

# %% [markdown]
# ![An image](https://editor.analyticsvidhya.com/uploads/80574left_right_skewed.jpg)

# %% [markdown]
# **Positive/right skewed distribution:**
#
# — Low values are frequent
# — Tail is on the higher value side
# — Higher value tail will make the mean greater than the median
#
# **Negative/left skewed distribution:**
#
# — High values are frequent
# — Tail is on the lower value side
# — Lower value tail will make the mean smaller than the median

# %% [markdown]
# **Probability Density Function(PDF)**
#
# If you know about Histogram then where you cut the data in bins, and visualize spread. But if we want to do a multiclass sort of analysis on numerical data, then it is difficult to do using Histogram and It can be easily be done using PDF. The probability density function is that line drawn within histogram only using KDE(kernel density estimation). So, if you see the KDE curve it passes by touching the corner of each bin. Hence using PDF we can draw side by side KDE and analysis multiclass data.

# %%
sns.FacetGrid(df_iris, hue='variety', height=6).map(sns.distplot, 'petal_length').add_legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# **Cumulative Distributive function(CDF)**
#
# CDF tells us that how much percentage of data is less than a particular number. To find the CDF we will add all the histogram bind before that point and the result will be my resultant CDF. Another method to do so is using Calculus using Area under the curve, so at what point you want CDF, plot the straight line from that and find the inner area. Hence on integrating PDF we get CDF and on differentiating CDF we get PDF.

# %% [markdown]
# In our case:
#
# CDF helps us to know the probability of point classifying correctly or wrong. let us understand the practical implementation of a petal length graph between all three classes.

# %% [markdown]
# ![An image](https://editor.analyticsvidhya.com/uploads/76854CDF_3.png)

# %% [markdown]
# Now we have to write a logic only using petal length to differentiate 3 classes. then using the above CDF we can smartly write it and analyze what is chances are to correctly classify the classes. setosa condition is simple. In Versicolor if we take point 5 that less than 5 is Versicolor then scratch the straight line from intersection point then we can say that 95 per cent values below 5 will be in Versicolor means we are correctly classifying at an accuracy of 95 per cent. so there are chances of making mistakes but you can tell the probability of making a wrong classification.

# %% [markdown]
# **Exploratory Data Analysis (EDA)**
#
# Now that we have some idea about the key measurements from descriptive statistics, we will visualize them on the Iris dataset using different graphical techniques or plots.
#
# We describe the following types of plots encountered often:
#
# Box Plot
#
# Swarm Plot
#
# Violin Plot
#
# Pair Plot

# %% [markdown]
# **Box Plot (or box-and-whisker plot)**
#
# The first plot we will explore is Box Plot. It summarizes the key statistical measures as follows.
#
# The box goes from the first quartile(Q1) to the third quartile(Q3). The vertical line within the the box indicates median value. The two whiskers (lower 25% of scores and upper 25% of scores) go from the quartile to the minimum and the maximum values.
#
# Interquartile Range (IQR): Middle 50% of scores, which is the range between the 25th and 75th percentile.
#
# Outliers: If a data point is below (Q1–1.5×IQR) or above (Q3 + 1.5×IQR), it is considered to be far from the central values and thus termed as outliers.

# %% [markdown]
# ![An image](https://miro.medium.com/max/700/1*lwdOZmhm_sRfIoYJtwqmGQ.png)

# %% [markdown]
# Iris data Box Plot 1: Comparison between the 3 categories for each numerical variable.
#
# X axis: Species Categories, Y axis: Numeric variable values in cm.

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import statistics 

# plot parameter set
params = {'legend.fontsize': 9
          , 'font.size': 16
          , 'font.serif': ['Computer Modern Roman']
          , 'axes.labelsize': 16
          , 'xtick.labelsize': 17
          , 'ytick.labelsize': 14
         }
plt.rcParams.update(params)

# comparison between 3 categories for each numerical variable
fig, (ax1, ax2) = plt.subplots(1,2,figsize=(16,5))

ax = sns.boxplot(x="variety", y="sepal_length",data=df_iris, palette="Set3", ax = ax1).set_title("Sepal length across species",fontsize=17)
ax = sns.boxplot(x="variety", y="sepal_width",data=df_iris, palette="Set3", ax = ax2).set_title("Sepal width across species",fontsize=17)

ax1.set_ylabel('')
ax1.set_xlabel('')

ax2.set_ylabel('')
ax2.set_xlabel('')

fig, (ax1, ax2) = plt.subplots(1,2,figsize=(16,5))

ax = sns.boxplot(x="variety", y="petal_length",data=df_iris, palette="Set3", ax = ax1).set_title("Petal length across species",fontsize=17)
ax = sns.boxplot(x="variety", y="petal_width",data=df_iris, palette="Set3", ax = ax2).set_title("Petal width across species",fontsize=17)

ax1.set_ylabel('')
ax1.set_xlabel('')

ax2.set_ylabel('')
ax2.set_xlabel('')

plt.show()

# %% [markdown]
# Iris data Box Plot 2: Comparison between the 4 numeric variables for each category.
#
# X axis: Numeric variables, Y axis: value in cm.

# %%
ax = sns.boxplot(data=iris_setosa, orient="v", palette="Set3").set_title("Iris setosa",fontsize=15)
plt.show()

ax = sns.boxplot(data=iris_virginica, orient="v",palette="Set3").set_title("Iris virginica",fontsize=15)
plt.show()

ax = sns.boxplot(data=iris_versicolor, orient="v",palette="Set3").set_title("Iris versicolor",fontsize=15)
plt.show()

# %% [markdown]
# For Iris setosa, the petal lengths are smaller than the sepal widths.
#
# Box plots can also help us to identify skewed data (we will discuss that with the next plot).
#
# Limitations: The box plots are focused on summary rather than detail. Thus, exact data points cannot be seen from the plot.

# %% [markdown]
# **Swarm Plot**
#
# Swarm plot is a type of categorical scatter plot. It shows the distribution of the data points adjusted along the categorical axis.
#
# Combining the swarm plot with the box plot will give a summary view as well as the data distribution.

# %%
fig, (ax1, ax2) = plt.subplots(1,2,figsize=(16,5))

ax = sns.boxplot(x="variety", y="sepal_length",data=df_iris, palette="Set3", ax = ax1).set_title("Sepal length across species",fontsize=17)
ax = sns.swarmplot(x="variety", y="sepal_length", data=df_iris, color="purple", ax = ax1)

ax = sns.boxplot(x="variety", y="sepal_width",data=df_iris, palette="Set3", ax = ax2).set_title("Sepal width across species",fontsize=17)
ax = sns.swarmplot(x="variety", y="sepal_width", data=df_iris, color="purple", ax = ax2)


ax1.set_ylabel('')
ax1.set_xlabel('')

ax2.set_ylabel('')
ax2.set_xlabel('')


fig, (ax1, ax2) = plt.subplots(1,2,figsize=(16,5))

ax = sns.boxplot(x="variety", y="petal_length",data=df_iris, palette="Set3", ax = ax1,).set_title("Petal length across species",fontsize=17)
ax = sns.swarmplot(x="variety", y="petal_length", data=df_iris, color="purple", ax = ax1)

ax = sns.boxplot(x="variety", y="petal_width",data=df_iris, palette="Set3", ax = ax2).set_title("Petal width across species",fontsize=17)
ax = sns.swarmplot(x="variety", y="petal_width", data=df_iris, color="purple", ax = ax2)

ax1.set_ylabel('')
ax1.set_xlabel('')

ax2.set_ylabel('')
ax2.set_xlabel('')

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 6.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 16.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Notice that we do not have any observation for Iris virginica sepal lengths between 6.6 cm and 6.7 cm.
#
# Sepal lengths of both Iris virginica and Iris versicolor are slightly left skewed, that is, low values are frequent and tail is on higher value side which makes the mean greater than the median (we will discuss this in detail with histogram).
#
# Limitations: The swarm plot does not scale well for large datasets since it plots all the data points.

# %% [markdown]
# **Violin Plot**
#
# Violin plot is a combination of box plot and KDE plot discussed before. It includes a kernel density estimation of the underlying data distribution.
#
# The violin plot can show all the key summary statistics as in the box plot. It can also show the sections where the probability of the values will be higher/smaller. The higher probability sections will be wider while the smaller probability sections will be narrower. This means that multimodal distributions can be visualized in a violin plot, but not in a box plot.
#
# Here is the violin plot on Iris data sepal length across different categories.

# %%
ax = sns.violinplot(x="variety", y="sepal_length", data=df_iris, palette="Set3")

plt.title("Sepal length violin plot",fontsize=16)

plt.xlabel('')
plt.ylabel('Sepal length in cm')
plt.show()

# %% [markdown]
# The white dot is the median
#
# Middle thick bar is the interquartile range
#
# The two thin lines are the whiskers we have seen before in the box plots
#
# The surrounding curve is the kernel density estimation of the underlying distribution
#
# Limitations: the violin plot may look misleadingly smooth for a small dataset.

# %% [markdown]
# **Pair Plot**
#
# Pair plot shows pairwise relationships in a data set.

# %%
ax = sns.pairplot(df_iris,hue="variety",diag_kind="hist", palette = 'husl')

plt.show()

# %% [markdown]
# In the above, the pair plot is showing:
#
# Scatter plots (shows the relationship between two variables) for non diagonal plots
#
# Histograms for the diagonal plots

# %% [markdown]
# **Quantifying the Correlation between Two Variables**
#
# Correlation measures the degree to which two variables are linearly related. Pearson’s correlation coefficient can be used to assign a numeric quantity for the same which can take any value between -1 to +1.
#
# Correlation coefficient 0 means that there is no linear relationship between the variables
#
# Correlation coefficient -1 means that the data points lie on a straight line with negative slope of -1
#
# Correlation coefficient +1 means that the data points lie on a straight line with positive slope of +1
#
# Here is a heat map of the Pearson correlation coefficients between the Iris variables:

# %%
corrMatrix = df_iris.corr(method='pearson')
sns.heatmap(corrMatrix, annot=True, cmap="Greens")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The variables with coefficient values close to +1 and -1 are highly correlated.
#
# For example, the petal lengths and the petal widths have high positive correlation coefficient (0.96).
#
# So for all the species, if the length of a petal is big/small, its width will also be proportionately big/small.

# %% [markdown]
# **summary of all the plots**

# %% [markdown]
# ![An image](https://miro.medium.com/max/700/1*c5BlY1uJCzUSGf2P1efJzQ.png)
